# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Alternate method
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
# populate the plot
ax.plot(x_axis, y_axis)

# %%
# ALternate method #2
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create the plot.
plt.plot(x_axis, y_axis)
# plt.show() can cause problems as it usually only be used once per session without restarting kernel
plt.show()

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

#Change the line color to green.
ax.plot(x_axis, y_axis, color="green")
#Change the marker to a diamond.
# resource: https://thispointer.com/matplotlib-line-plot-with-markers/
ax.plot(x_axis, y_axis, color="green", marker="D")
#Change the line width to 2 points.
ax.plot(x_axis, y_axis, color="green", marker="D", linewidth=2)
#Add a legend for the city of Boston.
ax.plot(x_axis, y_axis, color="green", marker="D", linewidth=2, label="Boston")
ax.legend()
#Add a title and axes labels.
ax.set_title("PyBer Fare by Month")
ax.set_xlabel("Date")
ax.set_ylabel("Fares ($)")
#Add a y-axis limit.
ax.set_ylim(0, 45)
#Add grid lines.
ax.grid()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the bar plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the hbar plot
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the hbar plot w/ reverse axes
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.barh(x_axis, y_axis)
# gca() = "get current axes" invert_yaxis() inverts y output order
plt.gca().invert_yaxis()

# %%
# SKillDrill 5.1.5
# Create the bar plot.
# Change the bar colors to magenta.
# Add a legend for the city of Boston.
plt.barh(x_axis, y_axis, color = "Magenta", label = "Boston")
plt.legend()

# Add a title and axes labels.
plt.xlabel("Date")
plt.ylabel("Fare($)")
plt.title("PyBer Fare by Month")

# Invert the y-axis so that January is at the top.
plt.gca().invert_yaxis()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, color="black", label='New York')
ax.legend()

# %%
# Create the hbar plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt() with opposite axes
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the hbar plot with ax.plt()
fig, ax = plt.subplots()

# Change the bar color to cyan.
# Add a legend for the city of Chicago.
# ax.barh(x_axis, y_axis, color = "cyan", label = "Chicago")
# ax.legend()

# Add a title and axes labels.
ax.set_ylabel("Date")
ax.set_xlabel("Fare($)")
ax.set_title("PyBer Fare by Month")

# Switch the axis so that the Fare($) data is on the x-axis.
ax.barh(x_axis, y_axis, color = "cyan", label = "Chicago")
ax.legend()
# Invert the y-axis data.
plt.gca().invert_yaxis()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]
plt.plot(x_axis, y_axis, 'o')

# %%
# Create the plot
# plt.scatter(x_axis, y_axis)


# Change the color of the markers to red.
# plt.scatter(x_axis, y_axis, c="red")

# Add a legend for the city of Chicago.
# plt.scatter(x_axis, y_axis, c="red", label = "Chicago")
# plt.legend()

# Add a title and axes labels.
plt.title("PyBer Fare by Month")
plt.ylabel("Date")
plt.xlabel("Fare($)")

# Switch the axis so that the Fare($) data is on the x-axis.
plt.scatter(y_axis, x_axis, c="red", label = "Chicago")
plt.legend()
# Add a limit for the x-axis data.
plt.xlim(0,50)
# Invert the y-axis so that January is at the top.
plt.gca().invert_yaxis()

# %%
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
# Scale the size based on multiplier in axes list
# Option 1: we can iterate through the y-axis data and multiply each data point by 3 using a for loop and add it to a new list
y_axis_larger = []
for data in y_axis:
  y_axis_larger.append(data*3)

plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
# Option 2: use list comprehension to replace many for and while loops
# https://docs.python.org/3.6/tutorial/datastructures.html#list-comprehensions
# new_list = [expression for item in list if conditional]
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
# Object-oriented scatter plot
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
# Object-oriented Bubble chart
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis)

# %%
# Skill Drill 5.1.7

# Object-oriented Bubble chart
fig, ax = plt.subplots()
# ax.scatter(x_axis, y_axis, s=y_axis)

# Change the color of the markers to sky blue.
# Resource for custom colors: https://matplotlib.org/stable/gallery/color/color_demo.html
# ax.scatter(x_axis, y_axis, s=y_axis, c="xkcd:sky blue")

# Change the size of the markers to 5 times each data point.
# ax.scatter(x_axis, y_axis, s = [i * 5 for i in y_axis], c="xkcd:sky blue")

# Make the color 20% transparent.
# ax.scatter(x_axis, y_axis, s = [i * 5 for i in y_axis], c="xkcd:sky blue", alpha = 0.2)

# Add a black edge color to the circles.
# ax.scatter(x_axis, y_axis, s = [i * 5 for i in y_axis], 
#           c="xkcd:sky blue", alpha = 0.2, marker= "o", edgecolors = "k")

# Make the linewidth of the circles 2 points.
# ax.scatter(x_axis, y_axis, s = [i * 5 for i in y_axis], 
#           c="xkcd:sky blue", alpha = 0.2, marker= "o", 
#            edgecolors = "k", linewidth = 2)

# Add a legend for the city of Boston.
# ax.scatter(x_axis, y_axis, s = [i * 5 for i in y_axis], 
#          c="xkcd:sky blue", alpha = 0.2, marker= "o", 
#           edgecolors = "k", linewidth = 2, label = "Boston")
# ax.legend()

# Add a title.
ax.set_ylabel("Date")
ax.set_xlabel("Fare($)")
ax.set_title("PyBer Fare by Month")

# Switch the axis so that the Fare($) data is on the x-axis.
ax.scatter(y_axis, x_axis, s = [i * 5 for i in y_axis], 
         c="skyblue", alpha = 0.2, marker= "o", 
          edgecolors = "k", linewidth = 2, label = "Boston")
ax.legend()

# Add a limit for the x-axis data.
ax.set_xlim(0,50)

# Invert the y-axis so that January is at the top.
plt.gca().invert_yaxis()

# %%
# Pie Charts using Matlab method
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
plt.show()

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

plt.show()

# %%
#Pie charts using Object-oriented method
fig, ax = plt.subplots()
ax.pie(y_axis,labels=x_axis)
plt.show()

# %%
# Skill Drill 5.1.8
# fig, ax = plt.subplots()
# ax.pie(y_axis,labels=x_axis)


# Add a percentage to one decimal place to each wedge of the pie.
#ax.pie(y_axis, labels = x_axis, autopct='%.1f%%')


# Increase the figure size to 8x8.
# Figure size has to be define before the plot
# Resource: https://stackoverflow.com/questions/52274643/figsize-in-matplotlib-is-not-changing-the-figure-size
# fig = plt.figure(figsize=(8, 8))
# ax = fig.add_subplot()
# ax.pie(y_axis, labels = x_axis, autopct='%.1f%%')

# Explode the two highest percentage months.
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot()

explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
# ax.pie(y_axis,
#       labels = x_axis, 
#       autopct='%.1f%%',
#       explode = explode_values)

# Add a shadow.
# Resource: https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.pie.html
# ax.pie(y_axis,
#       labels = x_axis,
#       autopct='%.1f%%',
#       explode = explode_values,
#       shadow = True)


# Add a start angle so that January is at the top.
# startangle: The angle by which the start of the pie is rotated, counterclockwise from the x-axis.
# ax.pie(y_axis,
#       labels = x_axis,
#       autopct='%.1f%%',
#       explode = explode_values,
#       shadow = True,
#       startangle = 90)


# Reverse the order so that the month order is in a clockwise direction.
# counterclock = True by default (CC) | False is clockwise
ax.pie(y_axis,
       labels = x_axis,
       autopct='%.1f%%',
       explode = explode_values,
       shadow = True,
       startangle = 90,
       counterclock = False)

# Add new colors of your own choosing or use the colors from the previous pie chart.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow",
          "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
ax.pie(y_axis,
       labels = x_axis,
       autopct='%.1f%%',
       explode = explode_values,
       shadow = True,
       startangle = 90,
       counterclock = False,
       colors = colors)

plt.show()
